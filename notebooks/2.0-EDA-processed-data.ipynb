# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from src.visualization import visualize as viz

# %%
DataVisualization = viz.DataVisualization(pd.read_csv("../data/processed/cat_6716.csv"), "text")

# %% [markdown]
# # Distribución de Registros por Categoría

# %%
DataVisualization.plot_categories_distribution()

# %% [markdown]
# # Distribución de la Longitud de los Textos

# %%
DataVisualization.plot_length_text_distribution()
# Out:
# C:\Users\Pc\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Pc\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Análisis de las palabras más frecuentes

# %%
DataVisualization.plot_word_cloud_most_common_words()

# %%
DataVisualization.plot_barh_most_common_words()

# %% [markdown]
# # Las palabras más largas y más cortas en el Dataset

# %%
DataVisualization.plot_barh_longest_words(25)

# %% [markdown]
# # Análisis de caracteres extraños presentes en los textos

# %%
DataVisualization.plot_characters_frequency()
# Out:
# ('ñ',)

# %% [markdown]
# # Brigramas y Trigramas más comunes en el Dataset

# %%
DataVisualization.plot_most_frequent_n_grams(15, 15)

# %% [markdown]
# # Comparación por categorias

# %% [markdown]
# ## Comparación de longitudes de texto por categoría

# %%
DataVisualization.compare_text_lengths_by_category()

# %% [markdown]
# ## Palabras más comunes por categoría

# %%
DataVisualization.plot_most_common_words_by_category()

# %%
DataVisualization.plot_word_clouds_by_category()

# %% [markdown]
# ## Bigramas más comunes por categoría

# %%
DataVisualization.plot_most_frequent_bigrams_comparison()

# %% [markdown]
# ## Trigramas más comunes por categoría

# %%
DataVisualization.plot_most_frequent_trigrams_comparison()
